# %%
# IMPORTING LIBRARIES
import random
import numpy as np
import pandas as pd
from copy import deepcopy

# CONFIG SETUP
suits = {'C':"♣",
         'D':"♦",
         'H':"♥",
         'S':"♠"}

ranks  = {  "J":3,
            "9":2,
            "A":1,"10":1,
            "K":0,"Q":0
}
delim = "|"
num_players= 8
starting_player = 1

# %%
class Card:
    def __init__(self, suit, rank):
        self.suit = suit
        self.rank = rank
        self.power = ranks[rank]

    def show(self):
        return self.rank + delim + self.suit

# %%
class Player:
    def __init__(self, play_n, init_hand):
        self.player_num = play_n
        self.hand = sorted(init_hand, key = lambda card: -1*card.power)

        self.team = play_n%2

    def pcard_sort(self, pcards):
        return sorted(pcards, key = lambda x: -1*x['card'].power)

    def strategy_1(self, round_cards, trump):
        if len(round_cards)==0:
            ### OPENING HAND
            sorted_hand = sorted(self.hand, key = lambda card: -1*card.power)

            if sorted_hand[0].rank == 'J':
                # If player has a J then play it
                play = sorted_hand[0]
            else:
                # Else play the lowest hand
                play = sorted_hand[-1]
            

        else:
            ### ONGOING ROUND
            reqd_suit = round_cards[0]['card'].suit
            sort_cards =sorted(round_cards, key = lambda play: -1*play['card'].power)


            top_card = sort_cards[0]
           
            vettus = self.pcard_sort([play for play in round_cards if play['card'].suit==trump])
            if len(vettus)>0: team_vettu = vettus[0]['player']%2==self.team
            else: team_vettu = False
            winning_team = (top_card['player']%2==0) or (team_vettu)
             

            # and (top_card[-1].power >= 2)
            # print(f"Team {self.team} winning: {winning_team}")

            if winning_team==self.team: func = max
            else: func = min

            # print(sort_cards)
            valid_cards = [card for card in self.hand if card.suit==reqd_suit]

            if len(valid_cards)!=0:
                # You HAVE a valid Suit Card
                if winning_team:
                    play = valid_cards[0]
                else:
                    play = valid_cards[-1]
                    
            else:
                # You DO NOT HAVE a valid Suit Card
                j = [card for card in self.hand if card.power==3]
                nonj = [card for card in self.hand if card.power<3]
                trumps = [card for card in self.hand if card.suit==trump]
                
                if winning_team:
                    if len(nonj)>0:
                        play = nonj[0]
                    else:
                        play = j[0]


                else:
                    if len(trumps)!=0:
                        play = trumps[-1]

                    elif len(nonj)!=0:
                        play = nonj[-1]

                    else:
                        play = j[-1]
                    
        self.hand.remove(play)
        return play

# %%
class Game:
    
    def __init__(self, num_players, show = False):
        ### STARTING THE GAME BY DIRTRIBUTING CARDS

        # Getting all cards set up
        cards = [[Card(suit, rank) for suit in suits.values()] for rank in ranks.keys()]
        # Converting List of Lists into a single List
        cards = [i for j in cards for i in j]

        if num_players >= 5: cards = cards*2

        
        # Shuffling the Cards
        random.shuffle(cards)
        
        # Splitting it to num_players in a dict
        self.players = {k+1: Player(k+1, list(hand)) for k, hand in enumerate(np.array_split(cards,num_players))}

        if show: self.show_hands()

        self.rounds = {}
        self.team_scores = {0:0, 1:0}


    def set_trump(self, trump):
        self.trump = trump
        print(f"\nTRUMP = {self.trump}")
    
    def show_hands(self):
        print("Current Hand of each Player")
        for player_num, player in self.players.items():
            print(str(player_num) + ") " + ", ".join([card.show() for card in player.hand]))
            
    def next_round_player(self, curr_round):
        start_card = curr_round[0]['card']
        start_suit = start_card.suit

        trumps = [play for play in curr_round if play['card'].suit==self.trump]
        vettu = len(trumps)>0
        if vettu:
            return sorted(trumps, key = lambda play: -1*play['card'].power)[0]['player']
        
        only_suit = sorted([play for play in curr_round if play['card'].suit==start_suit],
                           key = lambda play: -1*play['card'].power)
        return only_suit[0]['player'] 

    def round_statistics(self, curr_round):
        start_card = curr_round[0]['card']
        start_suit = start_card.suit

        trumps = [play for play in curr_round if play['card'].suit==self.trump]
        if len(trumps)>0: winning_team = sorted(trumps, key = lambda x: -1*x['card'].power)[0]['player']
        else: winning_team = sorted([pc for pc in curr_round if pc['card'].suit==start_suit], 
                                    key = lambda x: -1*x['card'].power)[0]['player']
            
        

        round_pts = sum([pc['card'].power for pc in curr_round])
        self.team_scores[winning_team%2]+= round_pts
        print("\n" + "\n".join([f"Team {k} Points: {v}" for k,v in self.team_scores.items()]))        


    def play_round(self, start_player=1):
        round_no = len(self.rounds.keys()) + 1
        print(f"\n\n\nRound {round_no}")

        round_stats = {}
        
        all_players = list(range(1,num_players+1))
        player_index = all_players.index(start_player)
        play_order = all_players[player_index:] + all_players[:player_index]

        self.round_cards = []
        for p,play in enumerate(play_order):
            play_card = self.players[play].strategy_1(self.round_cards, self.trump)
            print(f"{p+1}) Player {play}: {play_card.show()}")

            self.round_cards.append({'player':play, 'card':play_card})
        self.rounds[round_no] = self.round_cards

        self.round_statistics(self.round_cards)
        return self.next_round_player(self.round_cards)
    
    def play_game(self, round_starter=1):
        for k in range(1,int(56/num_players)):
            round_starter = self.play_round(round_starter)

# %%
new_game = Game(num_players, show = True)
game_stats = {0:{}, 1:{}}
for suit in suits.values():
    game_stats[0][suit] = {}; game_stats[1][suit] = {}
    for playn in range(1,num_players+1):
        game = deepcopy(new_game)
        game.set_trump(suit)
        game.play_game(playn)
        game_stats[0][suit][playn] = game.team_scores[0]
        game_stats[1][suit][playn] = game.team_scores[1]


display(pd.DataFrame(game_stats[0]).rename_axis('starter').T.style.background_gradient(cmap='Greens'))
new_game.show_hands()
display(pd.DataFrame(game_stats[1]).rename_axis('starter').T.style.background_gradient(cmap='Greens'))
# Out:
# Current Hand of each Player
# 1) 9|♣, 9|♦, 10|♦, 10|♣, 10|♦, Q|♦
# 2) J|♠, J|♥, A|♣, A|♦, 10|♥, A|♠
# 3) J|♦, J|♥, 9|♣, A|♥, K|♦, Q|♥
# 4) J|♣, J|♦, A|♥, K|♠, Q|♦, K|♥
# 5) 9|♥, 9|♠, 9|♠, 10|♥, K|♥, Q|♥
# 6) J|♣, 9|♦, A|♦, Q|♠, Q|♠, Q|♣
# 7) 9|♥, 10|♠, A|♠, A|♣, 10|♣, K|♣
# 8) J|♠, 10|♠, K|♣, K|♦, K|♠, Q|♣
#
# TRUMP = ♣
#
#
#
# Round 1
# 1) Player 1: Q|♦
# 2) Player 2: A|♦
# 3) Player 3: J|♦
# 4) Player 4: Q|♦
# 5) Player 5: Q|♥
# 6) Player 6: A|♦
# 7) Player 7: K|♣
# 8) Player 8: K|♦
#
# Team 0 Points: 0
# Team 1 Points: 5
#
#
#
# Round 2
# 1) Player 7: 10|♣
# 2) Player 8: Q|♣
# 3) Player 1: 9|♣
# 4) Player 2: A|♣
# 5) Player 3: 9|♣
# 6) Player 4: J|♣
# 7) Player 5: 9|♥
# 8) Player 6: J|♣
#
# Team 0 Points: 14
# Team 1 Points: 5
#
#
#
# Round 3
# 1) Player 4: J|♦
# 2) Player 5: 9|♠
# 3) Player 6: 9|♦
# 4) Player 7: 9|♥
# 5) Player 8: 10|♠
# 6) Player 1: 9|♦
# 7) Player 2: 10|♥
# 8) Player 3: K|♦
#
# Team 0 Points: 27
# Team 1 Points: 5
#
#
#
# Round 4
# 1) Player 4: K|♥
# 2) Player 5: 10|♥
# 3) Player 6: Q|♣
# 4) Player 7: A|♣
# 5) Player 8: K|♣
# 6) Player 1: 10|♦
# 7) Player 2: J|♥
# 8) Player 3: J|♥
#
# Team 0 Points: 27
# Team 1 Points: 14
#
#
#
# Round 5
# 1) Player 7: A|♠
# 2) Player 8: K|♠
# 3) Player 1: 10|♣
# 4) Player 2: A|♠
# 5) Player 3: A|♥
# 6) Player 4: K|♠
# 7) Player 5: 9|♠
# 8) Player 6: Q|♠
#
# Team 0 Points: 27
# Team 1 Points: 20
#
#
#
# Round 6
# 1) Player 1: 10|♦
# 2) Player 2: J|♠
# 3) Player 3: Q|♥
# 4) Player 4: A|♥
# 5) Player 5: K|♥
# 6) Player 6: Q|♠
# 7) Player 7: 10|♠
# 8) Player 8: J|♠
#
# Team 0 Points: 27
# Team 1 Points: 29
#
# TRUMP = ♣
#
#
#
# Round 1
# 1) Player 2: J|♠
# 2) Player 3: 9|♣
# 3) Player 4: K|♠
# 4) Player 5: 9|♠
# 5) Player 6: Q|♠
# 6) Player 7: 10|♠
# 7) Player 8: J|♠
# 8) Player 1: 9|♣
#
# Team 0 Points: 0
# Team 1 Points: 13
#
#
#
# Round 2
# 1) Player 3: J|♦
# 2) Player 4: Q|♦
# 3) Player 5: Q|♥
# 4) Player 6: A|♦
# 5) Player 7: K|♣
# 6) Player 8: K|♦
# 7) Player 1: 9|♦
# 8) Player 2: A|♦
#
# Team 0 Points: 0
# Team 1 Points: 20
#
#
#
# Round 3
# 1) Player 7: 10|♣
# 2) Player 8: Q|♣
# 3) Player 1: 10|♣
# 4) Player 2: A|♣
# 5) Player 3: A|♥
# 6) Player 4: J|♣
# 7) Player 5: 9|♥
# 8) Player 6: J|♣
#
# Team 0 Points: 12
# Team 1 Points: 20
#
#
#
# Round 4
# 1) Player 4: J|♦
# 2) Player 5: 9|♠
# 3) Player 6: 9|♦
# 4) Player 7: 9|♥
# 5) Player 8: 10|♠
# 6) Player 1: 10|♦
# 7) Player 2: 10|♥
# 8) Player 3: K|♦
#
# Team 0 Points: 24
# Team 1 Points: 20
#
#
#
# Round 5
# 1) Player 4: K|♥
# 2) Player 5: 10|♥
# 3) Player 6: Q|♣
# 4) Player 7: A|♣
# 5) Player 8: K|♣
# 6) Player 1: 10|♦
# 7) Player 2: J|♥
# 8) Player 3: J|♥
#
# Team 0 Points: 24
# Team 1 Points: 29
#
#
#
# Round 6
# 1) Player 7: A|♠
# 2) Player 8: K|♠
# 3) Player 1: Q|♦
# 4) Player 2: A|♠
# 5) Player 3: Q|♥
# 6) Player 4: A|♥
# 7) Player 5: K|♥
# 8) Player 6: Q|♠
#
# Team 0 Points: 24
# Team 1 Points: 32
#
# TRUMP = ♣
#
#
#
# Round 1
# 1) Player 3: J|♦
# 2) Player 4: Q|♦
# 3) Player 5: Q|♥
# 4) Player 6: A|♦
# 5) Player 7: K|♣
# 6) Player 8: K|♦
# 7) Player 1: 9|♦
# 8) Player 2: A|♦
#
# Team 0 Points: 0
# Team 1 Points: 7
#
#
#
# Round 2
# 1) Player 7: 10|♣
# 2) Player 8: Q|♣
# 3) Player 1: 9|♣
# 4) Player 2: A|♣
# 5) Player 3: 9|♣
# 6) Player 4: J|♣
# 7) Player 5: 9|♥
# 8) Player 6: J|♣
#
# Team 0 Points: 14
# Team 1 Points: 7
#
#
#
# Round 3
# 1) Player 4: J|♦
# 2) Player 5: 9|♠
# 3) Player 6: 9|♦
# 4) Player 7: 9|♥
# 5) Player 8: 10|♠
# 6) Player 1: 10|♦
# 7) Player 2: 10|♥
# 8) Player 3: K|♦
#
# Team 0 Points: 26
# Team 1 Points: 7
#
#
#
# Round 4
# 1) Player 4: K|♥
# 2) Player 5: 10|♥
# 3) Player 6: Q|♣
# 4) Player 7: A|♣
# 5) Player 8: K|♣
# 6) Player 1: 10|♣
# 7) Player 2: J|♥
# 8) Player 3: J|♥
#
# Team 0 Points: 26
# Team 1 Points: 16
#
#
#
# Round 5
# 1) Player 7: A|♠
# 2) Player 8: K|♠
# 3) Player 1: Q|♦
# 4) Player 2: A|♠
# 5) Player 3: Q|♥
# 6) Player 4: K|♠
# 7) Player 5: 9|♠
# 8) Player 6: Q|♠
#
# Team 0 Points: 26
# Team 1 Points: 20
#
#
#
# Round 6
# 1) Player 5: K|♥
# 2) Player 6: Q|♠
# 3) Player 7: 10|♠
# 4) Player 8: J|♠
# 5) Player 1: 10|♦
# 6) Player 2: J|♠
# 7) Player 3: A|♥
# 8) Player 4: A|♥
#
# Team 0 Points: 26
# Team 1 Points: 30
#
# TRUMP = ♣
#
#
#
# Round 1
# 1) Player 4: J|♣
# 2) Player 5: 9|♥
# 3) Player 6: J|♣
# 4) Player 7: A|♣
# 5) Player 8: K|♣
# 6) Player 1: 9|♣
# 7) Player 2: A|♣
# 8) Player 3: 9|♣
#
# Team 0 Points: 14
# Team 1 Points: 0
#
#
#
# Round 2
# 1) Player 4: J|♦
# 2) Player 5: 9|♠
# 3) Player 6: 9|♦
# 4) Player 7: 9|♥
# 5) Player 8: K|♦
# 6) Player 1: 9|♦
# 7) Player 2: A|♦
# 8) Player 3: J|♦
#
# Team 0 Points: 29
# Team 1 Points: 0
#
#
#
# Round 3
# 1) Player 4: K|♥
# 2) Player 5: 10|♥
# 3) Player 6: Q|♣
# 4) Player 7: K|♣
# 5) Player 8: 10|♠
# 6) Player 1: 10|♣
# 7) Player 2: 10|♥
# 8) Player 3: J|♥
#
# Team 0 Points: 29
# Team 1 Points: 7
#
#
#
# Round 4
# 1) Player 1: Q|♦
# 2) Player 2: A|♠
# 3) Player 3: K|♦
# 4) Player 4: Q|♦
# 5) Player 5: 9|♠
# 6) Player 6: A|♦
# 7) Player 7: 10|♣
# 8) Player 8: Q|♣
#
# Team 0 Points: 29
# Team 1 Points: 12
#
#
#
# Round 5
# 1) Player 7: A|♠
# 2) Player 8: K|♠
# 3) Player 1: 10|♦
# 4) Player 2: J|♠
# 5) Player 3: A|♥
# 6) Player 4: K|♠
# 7) Player 5: K|♥
# 8) Player 6: Q|♠
#
# Team 0 Points: 35
# Team 1 Points: 12
#
#
#
# Round 6
# 1) Player 2: J|♥
# 2) Player 3: Q|♥
# 3) Player 4: A|♥
# 4) Player 5: Q|♥
# 5) Player 6: Q|♠
# 6) Player 7: 10|♠
# 7) Player 8: J|♠
# 8) Player 1: 10|♦
#
# Team 0 Points: 44
# Team 1 Points: 12
#
# TRUMP = ♣
#
#
#
# Round 1
# 1) Player 5: Q|♥
# 2) Player 6: Q|♣
# 3) Player 7: 9|♥
# 4) Player 8: 10|♠
# 5) Player 1: 10|♣
# 6) Player 2: 10|♥
# 7) Player 3: J|♥
# 8) Player 4: K|♥
#
# Team 0 Points: 0
# Team 1 Points: 8
#
#
#
# Round 2
# 1) Player 1: Q|♦
# 2) Player 2: A|♦
# 3) Player 3: J|♦
# 4) Player 4: Q|♦
# 5) Player 5: K|♥
# 6) Player 6: A|♦
# 7) Player 7: K|♣
# 8) Player 8: K|♦
#
# Team 0 Points: 0
# Team 1 Points: 13
#
#
#
# Round 3
# 1) Player 7: 10|♣
# 2) Player 8: Q|♣
# 3) Player 1: 9|♣
# 4) Player 2: A|♣
# 5) Player 3: 9|♣
# 6) Player 4: J|♣
# 7) Player 5: 9|♥
# 8) Player 6: J|♣
#
# Team 0 Points: 14
# Team 1 Points: 13
#
#
#
# Round 4
# 1) Player 4: J|♦
# 2) Player 5: 9|♠
# 3) Player 6: 9|♦
# 4) Player 7: 10|♠
# 5) Player 8: K|♣
# 6) Player 1: 9|♦
# 7) Player 2: A|♠
# 8) Player 3: K|♦
#
# Team 0 Points: 25
# Team 1 Points: 13
#
#
#
# Round 5
# 1) Player 8: J|♠
# 2) Player 1: 10|♦
# 3) Player 2: J|♠
# 4) Player 3: A|♥
# 5) Player 4: K|♠
# 6) Player 5: 9|♠
# 7) Player 6: Q|♠
# 8) Player 7: A|♠
#
# Team 0 Points: 36
# Team 1 Points: 13
#
#
#
# Round 6
# 1) Player 8: K|♠
# 2) Player 1: 10|♦
# 3) Player 2: J|♥
# 4) Player 3: Q|♥
# 5) Player 4: A|♥
# 6) Player 5: 10|♥
# 7) Player 6: Q|♠
# 8) Player 7: A|♣
#
# Team 0 Points: 36
# Team 1 Points: 20
#
# TRUMP = ♣
#
#
#
# Round 1
# 1) Player 6: J|♣
# 2) Player 7: A|♣
# 3) Player 8: K|♣
# 4) Player 1: 9|♣
# 5) Player 2: A|♣
# 6) Player 3: 9|♣
# 7) Player 4: J|♣
# 8) Player 5: 9|♥
#
# Team 0 Points: 14
# Team 1 Points: 0
#
#
#
# Round 2
# 1) Player 6: Q|♣
# 2) Player 7: 10|♣
# 3) Player 8: Q|♣
# 4) Player 1: 10|♣
# 5) Player 2: A|♠
# 6) Player 3: A|♥
# 7) Player 4: K|♥
# 8) Player 5: 9|♠
#
# Team 0 Points: 14
# Team 1 Points: 6
#
#
#
# Round 3
# 1) Player 7: K|♣
# 2) Player 8: K|♠
# 3) Player 1: 9|♦
# 4) Player 2: 10|♥
# 5) Player 3: K|♦
# 6) Player 4: Q|♦
# 7) Player 5: 9|♠
# 8) Player 6: Q|♠
#
# Team 0 Points: 14
# Team 1 Points: 11
#
#
#
# Round 4
# 1) Player 7: A|♠
# 2) Player 8: 10|♠
# 3) Player 1: Q|♦
# 4) Player 2: J|♠
# 5) Player 3: Q|♥
# 6) Player 4: K|♠
# 7) Player 5: 10|♥
# 8) Player 6: Q|♠
#
# Team 0 Points: 20
# Team 1 Points: 11
#
#
#
# Round 5
# 1) Player 2: J|♥
# 2) Player 3: J|♥
# 3) Player 4: A|♥
# 4) Player 5: K|♥
# 5) Player 6: 9|♦
# 6) Player 7: 9|♥
# 7) Player 8: K|♦
# 8) Player 1: 10|♦
#
# Team 0 Points: 32
# Team 1 Points: 11
#
#
#
# Round 6
# 1) Player 2: A|♦
# 2) Player 3: J|♦
# 3) Player 4: J|♦
# 4) Player 5: Q|♥
# 5) Player 6: A|♦
# 6) Player 7: 10|♠
# 7) Player 8: J|♠
# 8) Player 1: 10|♦
#
# Team 0 Points: 32
# Team 1 Points: 24
#
# TRUMP = ♣
#
#
#
# Round 1
# 1) Player 7: K|♣
# 2) Player 8: Q|♣
# 3) Player 1: 9|♣
# 4) Player 2: A|♣
# 5) Player 3: 9|♣
# 6) Player 4: J|♣
# 7) Player 5: 9|♥
# 8) Player 6: J|♣
#
# Team 0 Points: 13
# Team 1 Points: 0
#
#
#
# Round 2
# 1) Player 4: J|♦
# 2) Player 5: 9|♠
# 3) Player 6: 9|♦
# 4) Player 7: 9|♥
# 5) Player 8: K|♦
# 6) Player 1: 9|♦
# 7) Player 2: A|♦
# 8) Player 3: J|♦
#
# Team 0 Points: 28
# Team 1 Points: 0
#
#
#
# Round 3
# 1) Player 4: K|♥
# 2) Player 5: 10|♥
# 3) Player 6: Q|♣
# 4) Player 7: 10|♣
# 5) Player 8: K|♣
# 6) Player 1: 10|♦
# 7) Player 2: 10|♥
# 8) Player 3: J|♥
#
# Team 0 Points: 28
# Team 1 Points: 7
#
#
#
# Round 4
# 1) Player 7: A|♣
# 2) Player 8: K|♠
# 3) Player 1: 10|♣
# 4) Player 2: A|♠
# 5) Player 3: A|♥
# 6) Player 4: Q|♦
# 7) Player 5: 9|♠
# 8) Player 6: Q|♠
#
# Team 0 Points: 28
# Team 1 Points: 13
#
#
#
# Round 5
# 1) Player 7: A|♠
# 2) Player 8: 10|♠
# 3) Player 1: Q|♦
# 4) Player 2: J|♠
# 5) Player 3: K|♦
# 6) Player 4: K|♠
# 7) Player 5: K|♥
# 8) Player 6: Q|♠
#
# Team 0 Points: 33
# Team 1 Points: 13
#
#
#
# Round 6
# 1) Player 2: J|♥
# 2) Player 3: Q|♥
# 3) Player 4: A|♥
# 4) Player 5: Q|♥
# 5) Player 6: A|♦
# 6) Player 7: 10|♠
# 7) Player 8: J|♠
# 8) Player 1: 10|♦
#
# Team 0 Points: 43
# Team 1 Points: 13
#
# TRUMP = ♣
#
#
#
# Round 1
# 1) Player 8: J|♠
# 2) Player 1: 9|♣
# 3) Player 2: J|♠
# 4) Player 3: 9|♣
# 5) Player 4: K|♠
# 6) Player 5: 9|♠
# 7) Player 6: Q|♠
# 8) Player 7: 10|♠
#
# Team 0 Points: 0
# Team 1 Points: 13
#
#
#
# Round 2
# 1) Player 1: Q|♦
# 2) Player 2: A|♦
# 3) Player 3: J|♦
# 4) Player 4: Q|♦
# 5) Player 5: Q|♥
# 6) Player 6: A|♦
# 7) Player 7: K|♣
# 8) Player 8: K|♦
#
# Team 0 Points: 0
# Team 1 Points: 18
#
#
#
# Round 3
# 1) Player 7: 10|♣
# 2) Player 8: Q|♣
# 3) Player 1: 10|♣
# 4) Player 2: A|♣
# 5) Player 3: A|♥
# 6) Player 4: J|♣
# 7) Player 5: 9|♥
# 8) Player 6: J|♣
#
# Team 0 Points: 12
# Team 1 Points: 18
#
#
#
# Round 4
# 1) Player 4: J|♦
# 2) Player 5: 9|♠
# 3) Player 6: 9|♦
# 4) Player 7: 9|♥
# 5) Player 8: 10|♠
# 6) Player 1: 9|♦
# 7) Player 2: 10|♥
# 8) Player 3: K|♦
#
# Team 0 Points: 25
# Team 1 Points: 18
#
#
#
# Round 5
# 1) Player 4: K|♥
# 2) Player 5: 10|♥
# 3) Player 6: Q|♣
# 4) Player 7: A|♣
# 5) Player 8: K|♣
# 6) Player 1: 10|♦
# 7) Player 2: J|♥
# 8) Player 3: J|♥
#
# Team 0 Points: 25
# Team 1 Points: 27
#
#
#
# Round 6
# 1) Player 7: A|♠
# 2) Player 8: K|♠
# 3) Player 1: 10|♦
# 4) Player 2: A|♠
# 5) Player 3: Q|♥
# 6) Player 4: A|♥
# 7) Player 5: K|♥
# 8) Player 6: Q|♠
#
# Team 0 Points: 25
# Team 1 Points: 31
#
# TRUMP = ♦
#
#
#
# Round 1
# 1) Player 1: Q|♦
# 2) Player 2: A|♦
# 3) Player 3: J|♦
# 4) Player 4: Q|♦
# 5) Player 5: 9|♥
# 6) Player 6: A|♦
# 7) Player 7: 9|♥
# 8) Player 8: K|♦
#
# Team 0 Points: 0
# Team 1 Points: 9
#
#
#
# Round 2
# 1) Player 3: J|♥
# 2) Player 4: K|♥
# 3) Player 5: Q|♥
# 4) Player 6: 9|♦
# 5) Player 7: K|♣
# 6) Player 8: 10|♠
# 7) Player 1: 10|♦
# 8) Player 2: J|♥
#
# Team 0 Points: 10
# Team 1 Points: 9
#
#
#
# Round 3
# 1) Player 6: J|♣
# 2) Player 7: A|♣
# 3) Player 8: K|♣
# 4) Player 1: 9|♣
# 5) Player 2: A|♣
# 6) Player 3: 9|♣
# 7) Player 4: J|♣
# 8) Player 5: 9|♠
#
# Team 0 Points: 24
# Team 1 Points: 9
#
#
#
# Round 4
# 1) Player 6: Q|♣
# 2) Player 7: 10|♣
# 3) Player 8: Q|♣
# 4) Player 1: 10|♣
# 5) Player 2: A|♠
# 6) Player 3: K|♦
# 7) Player 4: J|♦
# 8) Player 5: 9|♠
#
# Team 0 Points: 32
# Team 1 Points: 9
#
#
#
# Round 5
# 1) Player 4: K|♠
# 2) Player 5: 10|♥
# 3) Player 6: Q|♠
# 4) Player 7: A|♠
# 5) Player 8: K|♠
# 6) Player 1: 10|♦
# 7) Player 2: J|♠
# 8) Player 3: A|♥
#
# Team 0 Points: 32
# Team 1 Points: 16
#
#
#
# Round 6
# 1) Player 1: 9|♦
# 2) Player 2: 10|♥
# 3) Player 3: Q|♥
# 4) Player 4: A|♥
# 5) Player 5: K|♥
# 6) Player 6: Q|♠
# 7) Player 7: 10|♠
# 8) Player 8: J|♠
#
# Team 0 Points: 32
# Team 1 Points: 24
#
# TRUMP = ♦
#
#
#
# Round 1
# 1) Player 2: J|♠
# 2) Player 3: 9|♣
# 3) Player 4: K|♠
# 4) Player 5: 9|♠
# 5) Player 6: Q|♠
# 6) Player 7: 10|♠
# 7) Player 8: J|♠
# 8) Player 1: 9|♣
#
# Team 0 Points: 13
# Team 1 Points: 0
#
#
#
# Round 2
# 1) Player 2: J|♥
# 2) Player 3: J|♥
# 3) Player 4: A|♥
# 4) Player 5: 9|♥
# 5) Player 6: 9|♦
# 6) Player 7: 9|♥
# 7) Player 8: 10|♠
# 8) Player 1: 9|♦
#
# Team 0 Points: 29
# Team 1 Points: 0
#
#
#
# Round 3
# 1) Player 6: J|♣
# 2) Player 7: A|♣
# 3) Player 8: K|♣
# 4) Player 1: 10|♣
# 5) Player 2: A|♣
# 6) Player 3: A|♥
# 7) Player 4: J|♣
# 8) Player 5: 9|♠
#
# Team 0 Points: 41
# Team 1 Points: 0
#
#
#
# Round 4
# 1) Player 6: Q|♣
# 2) Player 7: 10|♣
# 3) Player 8: Q|♣
# 4) Player 1: Q|♦
# 5) Player 2: A|♦
# 6) Player 3: K|♦
# 7) Player 4: Q|♦
# 8) Player 5: Q|♥
#
# Team 0 Points: 43
# Team 1 Points: 0
#
#
#
# Round 5
# 1) Player 2: A|♠
# 2) Player 3: Q|♥
# 3) Player 4: K|♥
# 4) Player 5: 10|♥
# 5) Player 6: Q|♠
# 6) Player 7: A|♠
# 7) Player 8: K|♠
# 8) Player 1: 10|♦
#
# Team 0 Points: 43
# Team 1 Points: 4
#
#
#
# Round 6
# 1) Player 1: 10|♦
# 2) Player 2: 10|♥
# 3) Player 3: J|♦
# 4) Player 4: J|♦
# 5) Player 5: K|♥
# 6) Player 6: A|♦
# 7) Player 7: K|♣
# 8) Player 8: K|♦
#
# Team 0 Points: 43
# Team 1 Points: 13
#
# TRUMP = ♦
#
#
#
# Round 1
# 1) Player 3: J|♦
# 2) Player 4: Q|♦
# 3) Player 5: 9|♥
# 4) Player 6: A|♦
# 5) Player 7: 9|♥
# 6) Player 8: K|♦
# 7) Player 1: 9|♦
# 8) Player 2: A|♦
#
# Team 0 Points: 0
# Team 1 Points: 11
#
#
#
# Round 2
# 1) Player 3: J|♥
# 2) Player 4: K|♥
# 3) Player 5: Q|♥
# 4) Player 6: 9|♦
# 5) Player 7: K|♣
# 6) Player 8: 10|♠
# 7) Player 1: Q|♦
# 8) Player 2: J|♥
#
# Team 0 Points: 9
# Team 1 Points: 11
#
#
#
# Round 3
# 1) Player 6: J|♣
# 2) Player 7: A|♣
# 3) Player 8: K|♣
# 4) Player 1: 9|♣
# 5) Player 2: A|♣
# 6) Player 3: 9|♣
# 7) Player 4: J|♣
# 8) Player 5: 9|♠
#
# Team 0 Points: 23
# Team 1 Points: 11
#
#
#
# Round 4
# 1) Player 6: Q|♣
# 2) Player 7: 10|♣
# 3) Player 8: Q|♣
# 4) Player 1: 10|♣
# 5) Player 2: A|♠
# 6) Player 3: K|♦
# 7) Player 4: J|♦
# 8) Player 5: 9|♠
#
# Team 0 Points: 31
# Team 1 Points: 11
#
#
#
# Round 5
# 1) Player 4: K|♠
# 2) Player 5: 10|♥
# 3) Player 6: Q|♠
# 4) Player 7: A|♠
# 5) Player 8: K|♠
# 6) Player 1: 10|♦
# 7) Player 2: J|♠
# 8) Player 3: A|♥
#
# Team 0 Points: 31
# Team 1 Points: 18
#
#
#
# Round 6
# 1) Player 1: 10|♦
# 2) Player 2: 10|♥
# 3) Player 3: Q|♥
# 4) Player 4: A|♥
# 5) Player 5: K|♥
# 6) Player 6: Q|♠
# 7) Player 7: 10|♠
# 8) Player 8: J|♠
#
# Team 0 Points: 31
# Team 1 Points: 25
#
# TRUMP = ♦
#
#
#
# Round 1
# 1) Player 4: J|♣
# 2) Player 5: 9|♥
# 3) Player 6: J|♣
# 4) Player 7: A|♣
# 5) Player 8: K|♣
# 6) Player 1: 9|♣
# 7) Player 2: A|♣
# 8) Player 3: 9|♣
#
# Team 0 Points: 14
# Team 1 Points: 0
#
#
#
# Round 2
# 1) Player 4: J|♦
# 2) Player 5: 9|♠
# 3) Player 6: 9|♦
# 4) Player 7: 9|♥
# 5) Player 8: K|♦
# 6) Player 1: 9|♦
# 7) Player 2: A|♦
# 8) Player 3: J|♦
#
# Team 0 Points: 29
# Team 1 Points: 0
#
#
#
# Round 3
# 1) Player 4: K|♥
# 2) Player 5: 10|♥
# 3) Player 6: A|♦
# 4) Player 7: K|♣
# 5) Player 8: 10|♠
# 6) Player 1: Q|♦
# 7) Player 2: J|♥
# 8) Player 3: J|♥
#
# Team 0 Points: 38
# Team 1 Points: 0
#
#
#
# Round 4
# 1) Player 6: Q|♣
# 2) Player 7: 10|♣
# 3) Player 8: Q|♣
# 4) Player 1: 10|♣
# 5) Player 2: A|♠
# 6) Player 3: K|♦
# 7) Player 4: Q|♦
# 8) Player 5: 9|♠
#
# Team 0 Points: 38
# Team 1 Points: 5
#
#
#
# Round 5
# 1) Player 3: Q|♥
# 2) Player 4: A|♥
# 3) Player 5: K|♥
# 4) Player 6: Q|♠
# 5) Player 7: 10|♠
# 6) Player 8: K|♠
# 7) Player 1: 10|♦
# 8) Player 2: 10|♥
#
# Team 0 Points: 38
# Team 1 Points: 9
#
#
#
# Round 6
# 1) Player 1: 10|♦
# 2) Player 2: J|♠
# 3) Player 3: A|♥
# 4) Player 4: K|♠
# 5) Player 5: Q|♥
# 6) Player 6: Q|♠
# 7) Player 7: A|♠
# 8) Player 8: J|♠
#
# Team 0 Points: 38
# Team 1 Points: 18
#
# TRUMP = ♦
#
#
#
# Round 1
# 1) Player 5: Q|♥
# 2) Player 6: A|♦
# 3) Player 7: 9|♥
# 4) Player 8: 10|♠
# 5) Player 1: Q|♦
# 6) Player 2: J|♥
# 7) Player 3: J|♥
# 8) Player 4: A|♥
#
# Team 0 Points: 11
# Team 1 Points: 0
#
#
#
# Round 2
# 1) Player 6: J|♣
# 2) Player 7: A|♣
# 3) Player 8: K|♣
# 4) Player 1: 9|♣
# 5) Player 2: A|♣
# 6) Player 3: 9|♣
# 7) Player 4: J|♣
# 8) Player 5: 9|♥
#
# Team 0 Points: 25
# Team 1 Points: 0
#
#
#
# Round 3
# 1) Player 6: Q|♣
# 2) Player 7: 10|♣
# 3) Player 8: Q|♣
# 4) Player 1: 10|♣
# 5) Player 2: A|♦
# 6) Player 3: K|♦
# 7) Player 4: K|♠
# 8) Player 5: K|♥
#
# Team 0 Points: 28
# Team 1 Points: 0
#
#
#
# Round 4
# 1) Player 2: J|♠
# 2) Player 3: A|♥
# 3) Player 4: Q|♦
# 4) Player 5: 9|♠
# 5) Player 6: Q|♠
# 6) Player 7: 10|♠
# 7) Player 8: J|♠
# 8) Player 1: 9|♦
#
# Team 0 Points: 28
# Team 1 Points: 12
#
#
#
# Round 5
# 1) Player 1: 10|♦
# 2) Player 2: A|♠
# 3) Player 3: J|♦
# 4) Player 4: J|♦
# 5) Player 5: 9|♠
# 6) Player 6: 9|♦
# 7) Player 7: A|♠
# 8) Player 8: K|♦
#
# Team 0 Points: 28
# Team 1 Points: 25
#
#
#
# Round 6
# 1) Player 3: Q|♥
# 2) Player 4: K|♥
# 3) Player 5: 10|♥
# 4) Player 6: Q|♠
# 5) Player 7: K|♣
# 6) Player 8: K|♠
# 7) Player 1: 10|♦
# 8) Player 2: 10|♥
#
# Team 0 Points: 28
# Team 1 Points: 28
#
# TRUMP = ♦
#
#
#
# Round 1
# 1) Player 6: J|♣
# 2) Player 7: A|♣
# 3) Player 8: K|♣
# 4) Player 1: 9|♣
# 5) Player 2: A|♣
# 6) Player 3: 9|♣
# 7) Player 4: J|♣
# 8) Player 5: 9|♥
#
# Team 0 Points: 14
# Team 1 Points: 0
#
#
#
# Round 2
# 1) Player 6: Q|♣
# 2) Player 7: 10|♣
# 3) Player 8: Q|♣
# 4) Player 1: 10|♣
# 5) Player 2: A|♦
# 6) Player 3: K|♦
# 7) Player 4: A|♥
# 8) Player 5: Q|♥
#
# Team 0 Points: 18
# Team 1 Points: 0
#
#
#
# Round 3
# 1) Player 2: J|♠
# 2) Player 3: A|♥
# 3) Player 4: K|♠
# 4) Player 5: 9|♠
# 5) Player 6: Q|♠
# 6) Player 7: 10|♠
# 7) Player 8: J|♠
# 8) Player 1: 9|♦
#
# Team 0 Points: 18
# Team 1 Points: 12
#
#
#
# Round 4
# 1) Player 1: Q|♦
# 2) Player 2: A|♠
# 3) Player 3: J|♦
# 4) Player 4: Q|♦
# 5) Player 5: 9|♠
# 6) Player 6: A|♦
# 7) Player 7: 9|♥
# 8) Player 8: K|♦
#
# Team 0 Points: 18
# Team 1 Points: 21
#
#
#
# Round 5
# 1) Player 3: J|♥
# 2) Player 4: K|♥
# 3) Player 5: K|♥
# 4) Player 6: 9|♦
# 5) Player 7: K|♣
# 6) Player 8: 10|♠
# 7) Player 1: 10|♦
# 8) Player 2: J|♥
#
# Team 0 Points: 28
# Team 1 Points: 21
#
#
#
# Round 6
# 1) Player 6: Q|♠
# 2) Player 7: A|♠
# 3) Player 8: K|♠
# 4) Player 1: 10|♦
# 5) Player 2: 10|♥
# 6) Player 3: Q|♥
# 7) Player 4: J|♦
# 8) Player 5: 10|♥
#
# Team 0 Points: 35
# Team 1 Points: 21
#
# TRUMP = ♦
#
#
#
# Round 1
# 1) Player 7: K|♣
# 2) Player 8: Q|♣
# 3) Player 1: 10|♣
# 4) Player 2: A|♣
# 5) Player 3: 9|♣
# 6) Player 4: J|♣
# 7) Player 5: 9|♥
# 8) Player 6: J|♣
#
# Team 0 Points: 12
# Team 1 Points: 0
#
#
#
# Round 2
# 1) Player 4: J|♦
# 2) Player 5: 9|♠
# 3) Player 6: 9|♦
# 4) Player 7: 9|♥
# 5) Player 8: K|♦
# 6) Player 1: 9|♦
# 7) Player 2: A|♦
# 8) Player 3: J|♦
#
# Team 0 Points: 27
# Team 1 Points: 0
#
#
#
# Round 3
# 1) Player 4: K|♥
# 2) Player 5: 10|♥
# 3) Player 6: A|♦
# 4) Player 7: 10|♣
# 5) Player 8: 10|♠
# 6) Player 1: Q|♦
# 7) Player 2: J|♥
# 8) Player 3: J|♥
#
# Team 0 Points: 37
# Team 1 Points: 0
#
#
#
# Round 4
# 1) Player 6: Q|♣
# 2) Player 7: A|♣
# 3) Player 8: K|♣
# 4) Player 1: 9|♣
# 5) Player 2: A|♠
# 6) Player 3: K|♦
# 7) Player 4: Q|♦
# 8) Player 5: 9|♠
#
# Team 0 Points: 37
# Team 1 Points: 6
#
#
#
# Round 5
# 1) Player 3: Q|♥
# 2) Player 4: A|♥
# 3) Player 5: K|♥
# 4) Player 6: Q|♠
# 5) Player 7: 10|♠
# 6) Player 8: K|♠
# 7) Player 1: 10|♦
# 8) Player 2: 10|♥
#
# Team 0 Points: 37
# Team 1 Points: 10
#
#
#
# Round 6
# 1) Player 1: 10|♦
# 2) Player 2: J|♠
# 3) Player 3: A|♥
# 4) Player 4: K|♠
# 5) Player 5: Q|♥
# 6) Player 6: Q|♠
# 7) Player 7: A|♠
# 8) Player 8: J|♠
#
# Team 0 Points: 37
# Team 1 Points: 19
#
# TRUMP = ♦
#
#
#
# Round 1
# 1) Player 8: J|♠
# 2) Player 1: 9|♣
# 3) Player 2: J|♠
# 4) Player 3: 9|♣
# 5) Player 4: K|♠
# 6) Player 5: 9|♠
# 7) Player 6: Q|♠
# 8) Player 7: 10|♠
#
# Team 0 Points: 13
# Team 1 Points: 0
#
#
#
# Round 2
# 1) Player 8: Q|♣
# 2) Player 1: 10|♣
# 3) Player 2: A|♣
# 4) Player 3: K|♦
# 5) Player 4: J|♣
# 6) Player 5: 9|♥
# 7) Player 6: J|♣
# 8) Player 7: A|♣
#
# Team 0 Points: 13
# Team 1 Points: 11
#
#
#
# Round 3
# 1) Player 3: J|♦
# 2) Player 4: Q|♦
# 3) Player 5: 9|♠
# 4) Player 6: A|♦
# 5) Player 7: 9|♥
# 6) Player 8: K|♦
# 7) Player 1: 9|♦
# 8) Player 2: A|♦
#
# Team 0 Points: 13
# Team 1 Points: 22
#
#
#
# Round 4
# 1) Player 3: J|♥
# 2) Player 4: K|♥
# 3) Player 5: Q|♥
# 4) Player 6: 9|♦
# 5) Player 7: K|♣
# 6) Player 8: 10|♠
# 7) Player 1: Q|♦
# 8) Player 2: J|♥
#
# Team 0 Points: 22
# Team 1 Points: 22
#
#
#
# Round 5
# 1) Player 6: Q|♣
# 2) Player 7: 10|♣
# 3) Player 8: K|♣
# 4) Player 1: 10|♦
# 5) Player 2: A|♠
# 6) Player 3: A|♥
# 7) Player 4: J|♦
# 8) Player 5: 10|♥
#
# Team 0 Points: 30
# Team 1 Points: 22
#
#
#
# Round 6
# 1) Player 4: A|♥
# 2) Player 5: K|♥
# 3) Player 6: Q|♠
# 4) Player 7: A|♠
# 5) Player 8: K|♠
# 6) Player 1: 10|♦
# 7) Player 2: 10|♥
# 8) Player 3: Q|♥
#
# Team 0 Points: 30
# Team 1 Points: 26
#
# TRUMP = ♥
#
#
#
# Round 1
# 1) Player 1: Q|♦
# 2) Player 2: A|♦
# 3) Player 3: J|♦
# 4) Player 4: Q|♦
# 5) Player 5: Q|♥
# 6) Player 6: A|♦
# 7) Player 7: 9|♥
# 8) Player 8: K|♦
#
# Team 0 Points: 0
# Team 1 Points: 7
#
#
#
# Round 2
# 1) Player 7: K|♣
# 2) Player 8: Q|♣
# 3) Player 1: 10|♣
# 4) Player 2: A|♣
# 5) Player 3: 9|♣
# 6) Player 4: J|♣
# 7) Player 5: 9|♥
# 8) Player 6: J|♣
#
# Team 0 Points: 0
# Team 1 Points: 19
#
#
#
# Round 3
# 1) Player 5: K|♥
# 2) Player 6: Q|♣
# 3) Player 7: 10|♠
# 4) Player 8: K|♠
# 5) Player 1: 9|♣
# 6) Player 2: 10|♥
# 7) Player 3: Q|♥
# 8) Player 4: A|♥
#
# Team 0 Points: 5
# Team 1 Points: 19
#
#
#
# Round 4
# 1) Player 2: J|♠
# 2) Player 3: A|♥
# 3) Player 4: K|♠
# 4) Player 5: 9|♠
# 5) Player 6: Q|♠
# 6) Player 7: A|♠
# 7) Player 8: J|♠
# 8) Player 1: 9|♦
#
# Team 0 Points: 5
# Team 1 Points: 31
#
#
#
# Round 5
# 1) Player 3: J|♥
# 2) Player 4: K|♥
# 3) Player 5: 10|♥
# 4) Player 6: Q|♠
# 5) Player 7: A|♣
# 6) Player 8: K|♣
# 7) Player 1: 10|♦
# 8) Player 2: J|♥
#
# Team 0 Points: 5
# Team 1 Points: 40
#
#
#
# Round 6
# 1) Player 3: K|♦
# 2) Player 4: J|♦
# 3) Player 5: 9|♠
# 4) Player 6: 9|♦
# 5) Player 7: 10|♣
# 6) Player 8: 10|♠
# 7) Player 1: 10|♦
# 8) Player 2: A|♠
#
# Team 0 Points: 16
# Team 1 Points: 40
#
# TRUMP = ♥
#
#
#
# Round 1
# 1) Player 2: J|♠
# 2) Player 3: 9|♣
# 3) Player 4: K|♠
# 4) Player 5: 9|♠
# 5) Player 6: Q|♠
# 6) Player 7: 10|♠
# 7) Player 8: J|♠
# 8) Player 1: 9|♣
#
# Team 0 Points: 13
# Team 1 Points: 0
#
#
#
# Round 2
# 1) Player 2: J|♥
# 2) Player 3: J|♥
# 3) Player 4: A|♥
# 4) Player 5: 9|♥
# 5) Player 6: 9|♦
# 6) Player 7: 9|♥
# 7) Player 8: 10|♠
# 8) Player 1: 9|♦
#
# Team 0 Points: 29
# Team 1 Points: 0
#
#
#
# Round 3
# 1) Player 2: A|♠
# 2) Player 3: A|♥
# 3) Player 4: Q|♦
# 4) Player 5: 9|♠
# 5) Player 6: Q|♠
# 6) Player 7: A|♠
# 7) Player 8: K|♠
# 8) Player 1: 10|♦
#
# Team 0 Points: 29
# Team 1 Points: 6
#
#
#
# Round 4
# 1) Player 3: J|♦
# 2) Player 4: J|♦
# 3) Player 5: Q|♥
# 4) Player 6: A|♦
# 5) Player 7: A|♣
# 6) Player 8: K|♦
# 7) Player 1: 10|♦
# 8) Player 2: A|♦
#
# Team 0 Points: 29
# Team 1 Points: 16
#
#
#
# Round 5
# 1) Player 5: K|♥
# 2) Player 6: Q|♣
# 3) Player 7: 10|♣
# 4) Player 8: Q|♣
# 5) Player 1: 10|♣
# 6) Player 2: 10|♥
# 7) Player 3: Q|♥
# 8) Player 4: K|♥
#
# Team 0 Points: 32
# Team 1 Points: 16
#
#
#
# Round 6
# 1) Player 2: A|♣
# 2) Player 3: K|♦
# 3) Player 4: J|♣
# 4) Player 5: 10|♥
# 5) Player 6: J|♣
# 6) Player 7: K|♣
# 7) Player 8: K|♣
# 8) Player 1: Q|♦
#
# Team 0 Points: 32
# Team 1 Points: 24
#
# TRUMP = ♥
#
#
#
# Round 1
# 1) Player 3: J|♦
# 2) Player 4: Q|♦
# 3) Player 5: Q|♥
# 4) Player 6: A|♦
# 5) Player 7: 9|♥
# 6) Player 8: K|♦
# 7) Player 1: 9|♦
# 8) Player 2: A|♦
#
# Team 0 Points: 0
# Team 1 Points: 9
#
#
#
# Round 2
# 1) Player 7: K|♣
# 2) Player 8: Q|♣
# 3) Player 1: 10|♣
# 4) Player 2: A|♣
# 5) Player 3: 9|♣
# 6) Player 4: J|♣
# 7) Player 5: 9|♥
# 8) Player 6: J|♣
#
# Team 0 Points: 0
# Team 1 Points: 21
#
#
#
# Round 3
# 1) Player 5: K|♥
# 2) Player 6: Q|♣
# 3) Player 7: 10|♠
# 4) Player 8: K|♠
# 5) Player 1: 9|♣
# 6) Player 2: 10|♥
# 7) Player 3: Q|♥
# 8) Player 4: A|♥
#
# Team 0 Points: 5
# Team 1 Points: 21
#
#
#
# Round 4
# 1) Player 2: J|♠
# 2) Player 3: A|♥
# 3) Player 4: K|♠
# 4) Player 5: 9|♠
# 5) Player 6: Q|♠
# 6) Player 7: A|♠
# 7) Player 8: J|♠
# 8) Player 1: 10|♦
#
# Team 0 Points: 5
# Team 1 Points: 32
#
#
#
# Round 5
# 1) Player 3: J|♥
# 2) Player 4: K|♥
# 3) Player 5: 10|♥
# 4) Player 6: Q|♠
# 5) Player 7: A|♣
# 6) Player 8: K|♣
# 7) Player 1: 10|♦
# 8) Player 2: J|♥
#
# Team 0 Points: 5
# Team 1 Points: 41
#
#
#
# Round 6
# 1) Player 3: K|♦
# 2) Player 4: J|♦
# 3) Player 5: 9|♠
# 4) Player 6: 9|♦
# 5) Player 7: 10|♣
# 6) Player 8: 10|♠
# 7) Player 1: Q|♦
# 8) Player 2: A|♠
#
# Team 0 Points: 15
# Team 1 Points: 41
#
# TRUMP = ♥
#
#
#
# Round 1
# 1) Player 4: J|♣
# 2) Player 5: 9|♥
# 3) Player 6: J|♣
# 4) Player 7: A|♣
# 5) Player 8: K|♣
# 6) Player 1: 9|♣
# 7) Player 2: A|♣
# 8) Player 3: 9|♣
#
# Team 0 Points: 0
# Team 1 Points: 14
#
#
#
# Round 2
# 1) Player 5: Q|♥
# 2) Player 6: Q|♣
# 3) Player 7: 9|♥
# 4) Player 8: Q|♣
# 5) Player 1: 9|♦
# 6) Player 2: 10|♥
# 7) Player 3: J|♥
# 8) Player 4: K|♥
#
# Team 0 Points: 0
# Team 1 Points: 22
#
#
#
# Round 3
# 1) Player 3: J|♦
# 2) Player 4: Q|♦
# 3) Player 5: K|♥
# 4) Player 6: A|♦
# 5) Player 7: 10|♠
# 6) Player 8: K|♦
# 7) Player 1: 10|♦
# 8) Player 2: A|♦
#
# Team 0 Points: 0
# Team 1 Points: 29
#
#
#
# Round 4
# 1) Player 5: 10|♥
# 2) Player 6: Q|♠
# 3) Player 7: A|♠
# 4) Player 8: K|♠
# 5) Player 1: 10|♣
# 6) Player 2: J|♥
# 7) Player 3: A|♥
# 8) Player 4: A|♥
#
# Team 0 Points: 8
# Team 1 Points: 29
#
#
#
# Round 5
# 1) Player 2: J|♠
# 2) Player 3: K|♦
# 3) Player 4: K|♠
# 4) Player 5: 9|♠
# 5) Player 6: Q|♠
# 6) Player 7: 10|♣
# 7) Player 8: J|♠
# 8) Player 1: 10|♦
#
# Team 0 Points: 18
# Team 1 Points: 29
#
#
#
# Round 6
# 1) Player 2: A|♠
# 2) Player 3: Q|♥
# 3) Player 4: J|♦
# 4) Player 5: 9|♠
# 5) Player 6: 9|♦
# 6) Player 7: K|♣
# 7) Player 8: 10|♠
# 8) Player 1: Q|♦
#
# Team 0 Points: 18
# Team 1 Points: 38
#
# TRUMP = ♥
#
#
#
# Round 1
# 1) Player 5: Q|♥
# 2) Player 6: Q|♣
# 3) Player 7: 9|♥
# 4) Player 8: Q|♣
# 5) Player 1: 9|♣
# 6) Player 2: 10|♥
# 7) Player 3: J|♥
# 8) Player 4: K|♥
#
# Team 0 Points: 0
# Team 1 Points: 8
#
#
#
# Round 2
# 1) Player 3: J|♦
# 2) Player 4: Q|♦
# 3) Player 5: K|♥
# 4) Player 6: A|♦
# 5) Player 7: 10|♠
# 6) Player 8: K|♦
# 7) Player 1: 9|♦
# 8) Player 2: A|♦
#
# Team 0 Points: 0
# Team 1 Points: 16
#
#
#
# Round 3
# 1) Player 5: 10|♥
# 2) Player 6: Q|♠
# 3) Player 7: A|♠
# 4) Player 8: K|♠
# 5) Player 1: 10|♦
# 6) Player 2: J|♥
# 7) Player 3: A|♥
# 8) Player 4: A|♥
#
# Team 0 Points: 8
# Team 1 Points: 16
#
#
#
# Round 4
# 1) Player 2: J|♠
# 2) Player 3: 9|♣
# 3) Player 4: K|♠
# 4) Player 5: 9|♠
# 5) Player 6: Q|♠
# 6) Player 7: A|♣
# 7) Player 8: J|♠
# 8) Player 1: 10|♣
#
# Team 0 Points: 20
# Team 1 Points: 16
#
#
#
# Round 5
# 1) Player 2: A|♠
# 2) Player 3: K|♦
# 3) Player 4: J|♣
# 4) Player 5: 9|♠
# 5) Player 6: 9|♦
# 6) Player 7: 10|♣
# 7) Player 8: 10|♠
# 8) Player 1: 10|♦
#
# Team 0 Points: 20
# Team 1 Points: 27
#
#
#
# Round 6
# 1) Player 5: 9|♥
# 2) Player 6: J|♣
# 3) Player 7: K|♣
# 4) Player 8: K|♣
# 5) Player 1: Q|♦
# 6) Player 2: A|♣
# 7) Player 3: Q|♥
# 8) Player 4: J|♦
#
# Team 0 Points: 20
# Team 1 Points: 36
#
# TRUMP = ♥
#
#
#
# Round 1
# 1) Player 6: J|♣
# 2) Player 7: A|♣
# 3) Player 8: K|♣
# 4) Player 1: 9|♣
# 5) Player 2: A|♣
# 6) Player 3: 9|♣
# 7) Player 4: J|♣
# 8) Player 5: 9|♥
#
# Team 0 Points: 0
# Team 1 Points: 14
#
#
#
# Round 2
# 1) Player 5: Q|♥
# 2) Player 6: Q|♣
# 3) Player 7: 9|♥
# 4) Player 8: Q|♣
# 5) Player 1: 9|♦
# 6) Player 2: 10|♥
# 7) Player 3: J|♥
# 8) Player 4: K|♥
#
# Team 0 Points: 0
# Team 1 Points: 22
#
#
#
# Round 3
# 1) Player 3: J|♦
# 2) Player 4: Q|♦
# 3) Player 5: K|♥
# 4) Player 6: A|♦
# 5) Player 7: 10|♠
# 6) Player 8: K|♦
# 7) Player 1: 10|♦
# 8) Player 2: A|♦
#
# Team 0 Points: 0
# Team 1 Points: 29
#
#
#
# Round 4
# 1) Player 5: 10|♥
# 2) Player 6: Q|♠
# 3) Player 7: A|♠
# 4) Player 8: K|♠
# 5) Player 1: 10|♣
# 6) Player 2: J|♥
# 7) Player 3: A|♥
# 8) Player 4: A|♥
#
# Team 0 Points: 8
# Team 1 Points: 29
#
#
#
# Round 5
# 1) Player 2: J|♠
# 2) Player 3: K|♦
# 3) Player 4: K|♠
# 4) Player 5: 9|♠
# 5) Player 6: Q|♠
# 6) Player 7: 10|♣
# 7) Player 8: J|♠
# 8) Player 1: 10|♦
#
# Team 0 Points: 18
# Team 1 Points: 29
#
#
#
# Round 6
# 1) Player 2: A|♠
# 2) Player 3: Q|♥
# 3) Player 4: J|♦
# 4) Player 5: 9|♠
# 5) Player 6: 9|♦
# 6) Player 7: K|♣
# 7) Player 8: 10|♠
# 8) Player 1: Q|♦
#
# Team 0 Points: 18
# Team 1 Points: 38
#
# TRUMP = ♥
#
#
#
# Round 1
# 1) Player 7: K|♣
# 2) Player 8: Q|♣
# 3) Player 1: 10|♣
# 4) Player 2: A|♣
# 5) Player 3: 9|♣
# 6) Player 4: J|♣
# 7) Player 5: 9|♥
# 8) Player 6: J|♣
#
# Team 0 Points: 0
# Team 1 Points: 12
#
#
#
# Round 2
# 1) Player 5: Q|♥
# 2) Player 6: Q|♣
# 3) Player 7: 9|♥
# 4) Player 8: K|♠
# 5) Player 1: 9|♣
# 6) Player 2: 10|♥
# 7) Player 3: J|♥
# 8) Player 4: K|♥
#
# Team 0 Points: 0
# Team 1 Points: 20
#
#
#
# Round 3
# 1) Player 3: J|♦
# 2) Player 4: Q|♦
# 3) Player 5: K|♥
# 4) Player 6: A|♦
# 5) Player 7: 10|♠
# 6) Player 8: K|♦
# 7) Player 1: 9|♦
# 8) Player 2: A|♦
#
# Team 0 Points: 0
# Team 1 Points: 28
#
#
#
# Round 4
# 1) Player 5: 10|♥
# 2) Player 6: Q|♠
# 3) Player 7: A|♠
# 4) Player 8: K|♣
# 5) Player 1: 10|♦
# 6) Player 2: J|♥
# 7) Player 3: A|♥
# 8) Player 4: A|♥
#
# Team 0 Points: 8
# Team 1 Points: 28
#
#
#
# Round 5
# 1) Player 2: J|♠
# 2) Player 3: K|♦
# 3) Player 4: K|♠
# 4) Player 5: 9|♠
# 5) Player 6: Q|♠
# 6) Player 7: A|♣
# 7) Player 8: J|♠
# 8) Player 1: 10|♦
#
# Team 0 Points: 18
# Team 1 Points: 28
#
#
#
# Round 6
# 1) Player 2: A|♠
# 2) Player 3: Q|♥
# 3) Player 4: J|♦
# 4) Player 5: 9|♠
# 5) Player 6: 9|♦
# 6) Player 7: 10|♣
# 7) Player 8: 10|♠
# 8) Player 1: Q|♦
#
# Team 0 Points: 18
# Team 1 Points: 38
#
# TRUMP = ♥
#
#
#
# Round 1
# 1) Player 8: J|♠
# 2) Player 1: 9|♣
# 3) Player 2: J|♠
# 4) Player 3: 9|♣
# 5) Player 4: K|♠
# 6) Player 5: 9|♠
# 7) Player 6: Q|♠
# 8) Player 7: 10|♠
#
# Team 0 Points: 13
# Team 1 Points: 0
#
#
#
# Round 2
# 1) Player 8: Q|♣
# 2) Player 1: 10|♣
# 3) Player 2: A|♣
# 4) Player 3: Q|♥
# 5) Player 4: J|♣
# 6) Player 5: 9|♥
# 7) Player 6: J|♣
# 8) Player 7: A|♣
#
# Team 0 Points: 13
# Team 1 Points: 11
#
#
#
# Round 3
# 1) Player 5: Q|♥
# 2) Player 6: Q|♣
# 3) Player 7: 9|♥
# 4) Player 8: K|♠
# 5) Player 1: 9|♦
# 6) Player 2: 10|♥
# 7) Player 3: J|♥
# 8) Player 4: K|♥
#
# Team 0 Points: 13
# Team 1 Points: 19
#
#
#
# Round 4
# 1) Player 3: J|♦
# 2) Player 4: Q|♦
# 3) Player 5: K|♥
# 4) Player 6: A|♦
# 5) Player 7: A|♠
# 6) Player 8: K|♦
# 7) Player 1: 10|♦
# 8) Player 2: A|♦
#
# Team 0 Points: 13
# Team 1 Points: 26
#
#
#
# Round 5
# 1) Player 5: 10|♥
# 2) Player 6: Q|♠
# 3) Player 7: 10|♣
# 4) Player 8: K|♣
# 5) Player 1: 10|♦
# 6) Player 2: J|♥
# 7) Player 3: A|♥
# 8) Player 4: A|♥
#
# Team 0 Points: 21
# Team 1 Points: 26
#
#
#
# Round 6
# 1) Player 2: A|♠
# 2) Player 3: K|♦
# 3) Player 4: J|♦
# 4) Player 5: 9|♠
# 5) Player 6: 9|♦
# 6) Player 7: K|♣
# 7) Player 8: 10|♠
# 8) Player 1: Q|♦
#
# Team 0 Points: 21
# Team 1 Points: 35
#
# TRUMP = ♠
#
#
#
# Round 1
# 1) Player 1: Q|♦
# 2) Player 2: A|♦
# 3) Player 3: J|♦
# 4) Player 4: Q|♦
# 5) Player 5: 9|♠
# 6) Player 6: A|♦
# 7) Player 7: 9|♥
# 8) Player 8: K|♦
#
# Team 0 Points: 0
# Team 1 Points: 9
#
#
#
# Round 2
# 1) Player 5: Q|♥
# 2) Player 6: Q|♠
# 3) Player 7: A|♠
# 4) Player 8: K|♠
# 5) Player 1: 9|♣
# 6) Player 2: 10|♥
# 7) Player 3: J|♥
# 8) Player 4: K|♥
#
# Team 0 Points: 0
# Team 1 Points: 16
#
#
#
# Round 3
# 1) Player 7: K|♣
# 2) Player 8: Q|♣
# 3) Player 1: 10|♣
# 4) Player 2: A|♣
# 5) Player 3: 9|♣
# 6) Player 4: J|♣
# 7) Player 5: 9|♥
# 8) Player 6: J|♣
#
# Team 0 Points: 12
# Team 1 Points: 16
#
#
#
# Round 4
# 1) Player 4: J|♦
# 2) Player 5: 9|♠
# 3) Player 6: 9|♦
# 4) Player 7: 10|♠
# 5) Player 8: 10|♠
# 6) Player 1: 9|♦
# 7) Player 2: A|♠
# 8) Player 3: K|♦
#
# Team 0 Points: 12
# Team 1 Points: 28
#
#
#
# Round 5
# 1) Player 5: K|♥
# 2) Player 6: Q|♠
# 3) Player 7: 10|♣
# 4) Player 8: K|♣
# 5) Player 1: 10|♦
# 6) Player 2: J|♥
# 7) Player 3: A|♥
# 8) Player 4: A|♥
#
# Team 0 Points: 19
# Team 1 Points: 28
#
#
#
# Round 6
# 1) Player 6: Q|♣
# 2) Player 7: A|♣
# 3) Player 8: J|♠
# 4) Player 1: 10|♦
# 5) Player 2: J|♠
# 6) Player 3: Q|♥
# 7) Player 4: K|♠
# 8) Player 5: 10|♥
#
# Team 0 Points: 28
# Team 1 Points: 28
#
# TRUMP = ♠
#
#
#
# Round 1
# 1) Player 2: J|♠
# 2) Player 3: 9|♣
# 3) Player 4: K|♠
# 4) Player 5: 9|♠
# 5) Player 6: Q|♠
# 6) Player 7: 10|♠
# 7) Player 8: J|♠
# 8) Player 1: 9|♣
#
# Team 0 Points: 13
# Team 1 Points: 0
#
#
#
# Round 2
# 1) Player 2: J|♥
# 2) Player 3: J|♥
# 3) Player 4: A|♥
# 4) Player 5: 9|♥
# 5) Player 6: 9|♦
# 6) Player 7: 9|♥
# 7) Player 8: 10|♠
# 8) Player 1: 9|♦
#
# Team 0 Points: 29
# Team 1 Points: 0
#
#
#
# Round 3
# 1) Player 8: Q|♣
# 2) Player 1: 10|♣
# 3) Player 2: A|♣
# 4) Player 3: Q|♥
# 5) Player 4: J|♣
# 6) Player 5: 9|♠
# 7) Player 6: J|♣
# 8) Player 7: A|♣
#
# Team 0 Points: 29
# Team 1 Points: 11
#
#
#
# Round 4
# 1) Player 5: Q|♥
# 2) Player 6: Q|♠
# 3) Player 7: A|♠
# 4) Player 8: K|♠
# 5) Player 1: 10|♦
# 6) Player 2: 10|♥
# 7) Player 3: A|♥
# 8) Player 4: K|♥
#
# Team 0 Points: 29
# Team 1 Points: 15
#
#
#
# Round 5
# 1) Player 7: K|♣
# 2) Player 8: K|♣
# 3) Player 1: Q|♦
# 4) Player 2: A|♠
# 5) Player 3: K|♦
# 6) Player 4: Q|♦
# 7) Player 5: 10|♥
# 8) Player 6: Q|♣
#
# Team 0 Points: 31
# Team 1 Points: 15
#
#
#
# Round 6
# 1) Player 2: A|♦
# 2) Player 3: J|♦
# 3) Player 4: J|♦
# 4) Player 5: K|♥
# 5) Player 6: A|♦
# 6) Player 7: 10|♣
# 7) Player 8: K|♦
# 8) Player 1: 10|♦
#
# Team 0 Points: 31
# Team 1 Points: 25
#
# TRUMP = ♠
#
#
#
# Round 1
# 1) Player 3: J|♦
# 2) Player 4: Q|♦
# 3) Player 5: 9|♠
# 4) Player 6: A|♦
# 5) Player 7: 9|♥
# 6) Player 8: K|♦
# 7) Player 1: 9|♦
# 8) Player 2: A|♦
#
# Team 0 Points: 0
# Team 1 Points: 11
#
#
#
# Round 2
# 1) Player 5: Q|♥
# 2) Player 6: Q|♠
# 3) Player 7: A|♠
# 4) Player 8: K|♠
# 5) Player 1: 9|♣
# 6) Player 2: 10|♥
# 7) Player 3: J|♥
# 8) Player 4: K|♥
#
# Team 0 Points: 0
# Team 1 Points: 18
#
#
#
# Round 3
# 1) Player 7: K|♣
# 2) Player 8: Q|♣
# 3) Player 1: 10|♣
# 4) Player 2: A|♣
# 5) Player 3: 9|♣
# 6) Player 4: J|♣
# 7) Player 5: 9|♥
# 8) Player 6: J|♣
#
# Team 0 Points: 12
# Team 1 Points: 18
#
#
#
# Round 4
# 1) Player 4: J|♦
# 2) Player 5: 9|♠
# 3) Player 6: 9|♦
# 4) Player 7: 10|♠
# 5) Player 8: 10|♠
# 6) Player 1: 10|♦
# 7) Player 2: A|♠
# 8) Player 3: K|♦
#
# Team 0 Points: 12
# Team 1 Points: 29
#
#
#
# Round 5
# 1) Player 5: K|♥
# 2) Player 6: Q|♠
# 3) Player 7: 10|♣
# 4) Player 8: K|♣
# 5) Player 1: Q|♦
# 6) Player 2: J|♥
# 7) Player 3: A|♥
# 8) Player 4: A|♥
#
# Team 0 Points: 18
# Team 1 Points: 29
#
#
#
# Round 6
# 1) Player 6: Q|♣
# 2) Player 7: A|♣
# 3) Player 8: J|♠
# 4) Player 1: 10|♦
# 5) Player 2: J|♠
# 6) Player 3: Q|♥
# 7) Player 4: K|♠
# 8) Player 5: 10|♥
#
# Team 0 Points: 27
# Team 1 Points: 29
#
# TRUMP = ♠
#
#
#
# Round 1
# 1) Player 4: J|♣
# 2) Player 5: 9|♥
# 3) Player 6: J|♣
# 4) Player 7: A|♣
# 5) Player 8: K|♣
# 6) Player 1: 9|♣
# 7) Player 2: A|♣
# 8) Player 3: 9|♣
#
# Team 0 Points: 14
# Team 1 Points: 0
#
#
#
# Round 2
# 1) Player 4: J|♦
# 2) Player 5: 9|♠
# 3) Player 6: 9|♦
# 4) Player 7: 9|♥
# 5) Player 8: K|♦
# 6) Player 1: 9|♦
# 7) Player 2: A|♦
# 8) Player 3: J|♦
#
# Team 0 Points: 14
# Team 1 Points: 15
#
#
#
# Round 3
# 1) Player 5: Q|♥
# 2) Player 6: Q|♠
# 3) Player 7: A|♠
# 4) Player 8: K|♠
# 5) Player 1: 10|♦
# 6) Player 2: 10|♥
# 7) Player 3: J|♥
# 8) Player 4: K|♥
#
# Team 0 Points: 14
# Team 1 Points: 21
#
#
#
# Round 4
# 1) Player 7: K|♣
# 2) Player 8: Q|♣
# 3) Player 1: 10|♣
# 4) Player 2: A|♠
# 5) Player 3: Q|♥
# 6) Player 4: A|♥
# 7) Player 5: 9|♠
# 8) Player 6: Q|♣
#
# Team 0 Points: 14
# Team 1 Points: 26
#
#
#
# Round 5
# 1) Player 5: K|♥
# 2) Player 6: Q|♠
# 3) Player 7: 10|♠
# 4) Player 8: 10|♠
# 5) Player 1: 10|♦
# 6) Player 2: J|♥
# 7) Player 3: A|♥
# 8) Player 4: K|♠
#
# Team 0 Points: 14
# Team 1 Points: 33
#
#
#
# Round 6
# 1) Player 7: 10|♣
# 2) Player 8: J|♠
# 3) Player 1: Q|♦
# 4) Player 2: J|♠
# 5) Player 3: K|♦
# 6) Player 4: Q|♦
# 7) Player 5: 10|♥
# 8) Player 6: A|♦
#
# Team 0 Points: 23
# Team 1 Points: 33
#
# TRUMP = ♠
#
#
#
# Round 1
# 1) Player 5: Q|♥
# 2) Player 6: Q|♠
# 3) Player 7: 9|♥
# 4) Player 8: 10|♠
# 5) Player 1: Q|♦
# 6) Player 2: J|♥
# 7) Player 3: J|♥
# 8) Player 4: A|♥
#
# Team 0 Points: 10
# Team 1 Points: 0
#
#
#
# Round 2
# 1) Player 8: J|♠
# 2) Player 1: 9|♣
# 3) Player 2: J|♠
# 4) Player 3: 9|♣
# 5) Player 4: K|♠
# 6) Player 5: 9|♠
# 7) Player 6: Q|♠
# 8) Player 7: 10|♠
#
# Team 0 Points: 23
# Team 1 Points: 0
#
#
#
# Round 3
# 1) Player 8: Q|♣
# 2) Player 1: 10|♣
# 3) Player 2: A|♣
# 4) Player 3: Q|♥
# 5) Player 4: J|♣
# 6) Player 5: 9|♥
# 7) Player 6: J|♣
# 8) Player 7: A|♣
#
# Team 0 Points: 34
# Team 1 Points: 0
#
#
#
# Round 4
# 1) Player 4: J|♦
# 2) Player 5: 9|♠
# 3) Player 6: 9|♦
# 4) Player 7: A|♠
# 5) Player 8: K|♦
# 6) Player 1: 9|♦
# 7) Player 2: A|♦
# 8) Player 3: J|♦
#
# Team 0 Points: 34
# Team 1 Points: 14
#
#
#
# Round 5
# 1) Player 5: K|♥
# 2) Player 6: Q|♣
# 3) Player 7: K|♣
# 4) Player 8: K|♠
# 5) Player 1: 10|♦
# 6) Player 2: 10|♥
# 7) Player 3: A|♥
# 8) Player 4: K|♥
#
# Team 0 Points: 37
# Team 1 Points: 14
#
#
#
# Round 6
# 1) Player 8: K|♣
# 2) Player 1: 10|♦
# 3) Player 2: A|♠
# 4) Player 3: K|♦
# 5) Player 4: Q|♦
# 6) Player 5: 10|♥
# 7) Player 6: A|♦
# 8) Player 7: 10|♣
#
# Team 0 Points: 42
# Team 1 Points: 14
#
# TRUMP = ♠
#
#
#
# Round 1
# 1) Player 6: J|♣
# 2) Player 7: A|♣
# 3) Player 8: K|♣
# 4) Player 1: 9|♣
# 5) Player 2: A|♣
# 6) Player 3: 9|♣
# 7) Player 4: J|♣
# 8) Player 5: 9|♥
#
# Team 0 Points: 14
# Team 1 Points: 0
#
#
#
# Round 2
# 1) Player 6: Q|♣
# 2) Player 7: 10|♣
# 3) Player 8: Q|♣
# 4) Player 1: 10|♣
# 5) Player 2: A|♠
# 6) Player 3: Q|♥
# 7) Player 4: A|♥
# 8) Player 5: 9|♠
#
# Team 0 Points: 14
# Team 1 Points: 6
#
#
#
# Round 3
# 1) Player 5: Q|♥
# 2) Player 6: Q|♠
# 3) Player 7: 9|♥
# 4) Player 8: 10|♠
# 5) Player 1: Q|♦
# 6) Player 2: J|♥
# 7) Player 3: J|♥
# 8) Player 4: K|♥
#
# Team 0 Points: 23
# Team 1 Points: 6
#
#
#
# Round 4
# 1) Player 8: J|♠
# 2) Player 1: 9|♦
# 3) Player 2: J|♠
# 4) Player 3: A|♥
# 5) Player 4: K|♠
# 6) Player 5: 9|♠
# 7) Player 6: Q|♠
# 8) Player 7: 10|♠
#
# Team 0 Points: 35
# Team 1 Points: 6
#
#
#
# Round 5
# 1) Player 8: K|♠
# 2) Player 1: 10|♦
# 3) Player 2: A|♦
# 4) Player 3: K|♦
# 5) Player 4: Q|♦
# 6) Player 5: K|♥
# 7) Player 6: 9|♦
# 8) Player 7: A|♠
#
# Team 0 Points: 35
# Team 1 Points: 11
#
#
#
# Round 6
# 1) Player 7: K|♣
# 2) Player 8: K|♦
# 3) Player 1: 10|♦
# 4) Player 2: 10|♥
# 5) Player 3: J|♦
# 6) Player 4: J|♦
# 7) Player 5: 10|♥
# 8) Player 6: A|♦
#
# Team 0 Points: 35
# Team 1 Points: 21
#
# TRUMP = ♠
#
#
#
# Round 1
# 1) Player 7: K|♣
# 2) Player 8: Q|♣
# 3) Player 1: 10|♣
# 4) Player 2: A|♣
# 5) Player 3: 9|♣
# 6) Player 4: J|♣
# 7) Player 5: 9|♥
# 8) Player 6: J|♣
#
# Team 0 Points: 12
# Team 1 Points: 0
#
#
#
# Round 2
# 1) Player 4: J|♦
# 2) Player 5: 9|♠
# 3) Player 6: 9|♦
# 4) Player 7: 9|♥
# 5) Player 8: K|♦
# 6) Player 1: 9|♦
# 7) Player 2: A|♦
# 8) Player 3: J|♦
#
# Team 0 Points: 12
# Team 1 Points: 15
#
#
#
# Round 3
# 1) Player 5: Q|♥
# 2) Player 6: Q|♠
# 3) Player 7: A|♠
# 4) Player 8: K|♠
# 5) Player 1: 9|♣
# 6) Player 2: 10|♥
# 7) Player 3: J|♥
# 8) Player 4: K|♥
#
# Team 0 Points: 12
# Team 1 Points: 22
#
#
#
# Round 4
# 1) Player 7: 10|♣
# 2) Player 8: K|♣
# 3) Player 1: Q|♦
# 4) Player 2: A|♠
# 5) Player 3: Q|♥
# 6) Player 4: A|♥
# 7) Player 5: 9|♠
# 8) Player 6: Q|♣
#
# Team 0 Points: 12
# Team 1 Points: 27
#
#
#
# Round 5
# 1) Player 5: K|♥
# 2) Player 6: Q|♠
# 3) Player 7: 10|♠
# 4) Player 8: 10|♠
# 5) Player 1: 10|♦
# 6) Player 2: J|♥
# 7) Player 3: A|♥
# 8) Player 4: K|♠
#
# Team 0 Points: 12
# Team 1 Points: 34
#
#
#
# Round 6
# 1) Player 7: A|♣
# 2) Player 8: J|♠
# 3) Player 1: 10|♦
# 4) Player 2: J|♠
# 5) Player 3: K|♦
# 6) Player 4: Q|♦
# 7) Player 5: 10|♥
# 8) Player 6: A|♦
#
# Team 0 Points: 22
# Team 1 Points: 34
#
# TRUMP = ♠
#
#
#
# Round 1
# 1) Player 8: J|♠
# 2) Player 1: 9|♣
# 3) Player 2: J|♠
# 4) Player 3: 9|♣
# 5) Player 4: K|♠
# 6) Player 5: 9|♠
# 7) Player 6: Q|♠
# 8) Player 7: 10|♠
#
# Team 0 Points: 13
# Team 1 Points: 0
#
#
#
# Round 2
# 1) Player 8: Q|♣
# 2) Player 1: 10|♣
# 3) Player 2: A|♣
# 4) Player 3: Q|♥
# 5) Player 4: J|♣
# 6) Player 5: 9|♥
# 7) Player 6: J|♣
# 8) Player 7: A|♣
#
# Team 0 Points: 24
# Team 1 Points: 0
#
#
#
# Round 3
# 1) Player 4: J|♦
# 2) Player 5: 9|♠
# 3) Player 6: 9|♦
# 4) Player 7: 9|♥
# 5) Player 8: K|♦
# 6) Player 1: 9|♦
# 7) Player 2: A|♦
# 8) Player 3: J|♦
#
# Team 0 Points: 24
# Team 1 Points: 15
#
#
#
# Round 4
# 1) Player 5: Q|♥
# 2) Player 6: Q|♠
# 3) Player 7: A|♠
# 4) Player 8: K|♠
# 5) Player 1: 10|♦
# 6) Player 2: 10|♥
# 7) Player 3: J|♥
# 8) Player 4: K|♥
#
# Team 0 Points: 24
# Team 1 Points: 21
#
#
#
# Round 5
# 1) Player 7: K|♣
# 2) Player 8: K|♣
# 3) Player 1: Q|♦
# 4) Player 2: A|♠
# 5) Player 3: A|♥
# 6) Player 4: A|♥
# 7) Player 5: 10|♥
# 8) Player 6: Q|♣
#
# Team 0 Points: 28
# Team 1 Points: 21
#
#
#
# Round 6
# 1) Player 2: J|♥
# 2) Player 3: K|♦
# 3) Player 4: Q|♦
# 4) Player 5: K|♥
# 5) Player 6: A|♦
# 6) Player 7: 10|♣
# 7) Player 8: 10|♠
# 8) Player 1: 10|♦
#
# Team 0 Points: 35
# Team 1 Points: 21
# <style type="text/css">
# #T_2c629_row0_col0, #T_2c629_row0_col2 {
#   background-color: #319a50;
#   color: #f1f1f1;
# }
# #T_2c629_row0_col1, #T_2c629_row2_col0, #T_2c629_row2_col2, #T_2c629_row2_col3, #T_2c629_row2_col4, #T_2c629_row2_col5, #T_2c629_row2_col6, #T_2c629_row2_col7 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_2c629_row0_col3, #T_2c629_row0_col6, #T_2c629_row1_col0, #T_2c629_row1_col1, #T_2c629_row1_col2, #T_2c629_row1_col5, #T_2c629_row3_col4, #T_2c629_row3_col5, #T_2c629_row3_col7 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_2c629_row0_col4 {
#   background-color: #289049;
#   color: #f1f1f1;
# }
# #T_2c629_row0_col5 {
#   background-color: #0e7936;
#   color: #f1f1f1;
# }
# #T_2c629_row0_col7 {
#   background-color: #bce4b5;
#   color: #000000;
# }
# #T_2c629_row1_col3 {
#   background-color: #1e8741;
#   color: #f1f1f1;
# }
# #T_2c629_row1_col4 {
#   background-color: #a4da9e;
#   color: #000000;
# }
# #T_2c629_row1_col6 {
#   background-color: #208843;
#   color: #f1f1f1;
# }
# #T_2c629_row1_col7 {
#   background-color: #3da65a;
#   color: #f1f1f1;
# }
# #T_2c629_row2_col1 {
#   background-color: #91d28e;
#   color: #000000;
# }
# #T_2c629_row3_col0, #T_2c629_row3_col2 {
#   background-color: #228a44;
#   color: #f1f1f1;
# }
# #T_2c629_row3_col1 {
#   background-color: #a3da9d;
#   color: #000000;
# }
# #T_2c629_row3_col3 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_2c629_row3_col6 {
#   background-color: #ddf2d8;
#   color: #000000;
# }
# </style>
# <table id="T_2c629">
#   <thead>
#     <tr>
#       <th class="index_name level0" >starter</th>
#       <th id="T_2c629_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_2c629_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_2c629_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_2c629_level0_col3" class="col_heading level0 col3" >4</th>
#       <th id="T_2c629_level0_col4" class="col_heading level0 col4" >5</th>
#       <th id="T_2c629_level0_col5" class="col_heading level0 col5" >6</th>
#       <th id="T_2c629_level0_col6" class="col_heading level0 col6" >7</th>
#       <th id="T_2c629_level0_col7" class="col_heading level0 col7" >8</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2c629_level0_row0" class="row_heading level0 row0" >♣</th>
#       <td id="T_2c629_row0_col0" class="data row0 col0" >27</td>
#       <td id="T_2c629_row0_col1" class="data row0 col1" >24</td>
#       <td id="T_2c629_row0_col2" class="data row0 col2" >26</td>
#       <td id="T_2c629_row0_col3" class="data row0 col3" >44</td>
#       <td id="T_2c629_row0_col4" class="data row0 col4" >36</td>
#       <td id="T_2c629_row0_col5" class="data row0 col5" >32</td>
#       <td id="T_2c629_row0_col6" class="data row0 col6" >43</td>
#       <td id="T_2c629_row0_col7" class="data row0 col7" >25</td>
#     </tr>
#     <tr>
#       <th id="T_2c629_level0_row1" class="row_heading level0 row1" >♦</th>
#       <td id="T_2c629_row1_col0" class="data row1 col0" >32</td>
#       <td id="T_2c629_row1_col1" class="data row1 col1" >43</td>
#       <td id="T_2c629_row1_col2" class="data row1 col2" >31</td>
#       <td id="T_2c629_row1_col3" class="data row1 col3" >38</td>
#       <td id="T_2c629_row1_col4" class="data row1 col4" >28</td>
#       <td id="T_2c629_row1_col5" class="data row1 col5" >35</td>
#       <td id="T_2c629_row1_col6" class="data row1 col6" >37</td>
#       <td id="T_2c629_row1_col7" class="data row1 col7" >30</td>
#     </tr>
#     <tr>
#       <th id="T_2c629_level0_row2" class="row_heading level0 row2" >♥</th>
#       <td id="T_2c629_row2_col0" class="data row2 col0" >16</td>
#       <td id="T_2c629_row2_col1" class="data row2 col1" >32</td>
#       <td id="T_2c629_row2_col2" class="data row2 col2" >15</td>
#       <td id="T_2c629_row2_col3" class="data row2 col3" >18</td>
#       <td id="T_2c629_row2_col4" class="data row2 col4" >20</td>
#       <td id="T_2c629_row2_col5" class="data row2 col5" >18</td>
#       <td id="T_2c629_row2_col6" class="data row2 col6" >18</td>
#       <td id="T_2c629_row2_col7" class="data row2 col7" >21</td>
#     </tr>
#     <tr>
#       <th id="T_2c629_level0_row3" class="row_heading level0 row3" >♠</th>
#       <td id="T_2c629_row3_col0" class="data row3 col0" >28</td>
#       <td id="T_2c629_row3_col1" class="data row3 col1" >31</td>
#       <td id="T_2c629_row3_col2" class="data row3 col2" >27</td>
#       <td id="T_2c629_row3_col3" class="data row3 col3" >23</td>
#       <td id="T_2c629_row3_col4" class="data row3 col4" >42</td>
#       <td id="T_2c629_row3_col5" class="data row3 col5" >35</td>
#       <td id="T_2c629_row3_col6" class="data row3 col6" >22</td>
#       <td id="T_2c629_row3_col7" class="data row3 col7" >35</td>
#     </tr>
#   </tbody>
# </table>
# Current Hand of each Player
# 1) 9|♣, 9|♦, 10|♦, 10|♣, 10|♦, Q|♦
# 2) J|♠, J|♥, A|♣, A|♦, 10|♥, A|♠
# 3) J|♦, J|♥, 9|♣, A|♥, K|♦, Q|♥
# 4) J|♣, J|♦, A|♥, K|♠, Q|♦, K|♥
# 5) 9|♥, 9|♠, 9|♠, 10|♥, K|♥, Q|♥
# 6) J|♣, 9|♦, A|♦, Q|♠, Q|♠, Q|♣
# 7) 9|♥, 10|♠, A|♠, A|♣, 10|♣, K|♣
# 8) J|♠, 10|♠, K|♣, K|♦, K|♠, Q|♣
# <style type="text/css">
# #T_4f142_row0_col0, #T_4f142_row0_col2 {
#   background-color: #b4e1ad;
#   color: #000000;
# }
# #T_4f142_row0_col1, #T_4f142_row2_col0, #T_4f142_row2_col2, #T_4f142_row2_col3, #T_4f142_row2_col4, #T_4f142_row2_col5, #T_4f142_row2_col6, #T_4f142_row2_col7 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_4f142_row0_col3, #T_4f142_row0_col6, #T_4f142_row1_col0, #T_4f142_row1_col1, #T_4f142_row1_col2, #T_4f142_row1_col5, #T_4f142_row3_col4, #T_4f142_row3_col5, #T_4f142_row3_col7 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_4f142_row0_col4 {
#   background-color: #c1e6ba;
#   color: #000000;
# }
# #T_4f142_row0_col5 {
#   background-color: #d9f0d3;
#   color: #000000;
# }
# #T_4f142_row0_col7 {
#   background-color: #2c944c;
#   color: #f1f1f1;
# }
# #T_4f142_row1_col3 {
#   background-color: #cbebc5;
#   color: #000000;
# }
# #T_4f142_row1_col4 {
#   background-color: #3fa85b;
#   color: #f1f1f1;
# }
# #T_4f142_row1_col6 {
#   background-color: #caeac3;
#   color: #000000;
# }
# #T_4f142_row1_col7 {
#   background-color: #a7dba0;
#   color: #000000;
# }
# #T_4f142_row2_col1 {
#   background-color: #53b466;
#   color: #f1f1f1;
# }
# #T_4f142_row3_col0, #T_4f142_row3_col2 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_4f142_row3_col1 {
#   background-color: #3fa95c;
#   color: #f1f1f1;
# }
# #T_4f142_row3_col3 {
#   background-color: #137d39;
#   color: #f1f1f1;
# }
# #T_4f142_row3_col6 {
#   background-color: #097532;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4f142">
#   <thead>
#     <tr>
#       <th class="index_name level0" >starter</th>
#       <th id="T_4f142_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_4f142_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_4f142_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_4f142_level0_col3" class="col_heading level0 col3" >4</th>
#       <th id="T_4f142_level0_col4" class="col_heading level0 col4" >5</th>
#       <th id="T_4f142_level0_col5" class="col_heading level0 col5" >6</th>
#       <th id="T_4f142_level0_col6" class="col_heading level0 col6" >7</th>
#       <th id="T_4f142_level0_col7" class="col_heading level0 col7" >8</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f142_level0_row0" class="row_heading level0 row0" >♣</th>
#       <td id="T_4f142_row0_col0" class="data row0 col0" >29</td>
#       <td id="T_4f142_row0_col1" class="data row0 col1" >32</td>
#       <td id="T_4f142_row0_col2" class="data row0 col2" >30</td>
#       <td id="T_4f142_row0_col3" class="data row0 col3" >12</td>
#       <td id="T_4f142_row0_col4" class="data row0 col4" >20</td>
#       <td id="T_4f142_row0_col5" class="data row0 col5" >24</td>
#       <td id="T_4f142_row0_col6" class="data row0 col6" >13</td>
#       <td id="T_4f142_row0_col7" class="data row0 col7" >31</td>
#     </tr>
#     <tr>
#       <th id="T_4f142_level0_row1" class="row_heading level0 row1" >♦</th>
#       <td id="T_4f142_row1_col0" class="data row1 col0" >24</td>
#       <td id="T_4f142_row1_col1" class="data row1 col1" >13</td>
#       <td id="T_4f142_row1_col2" class="data row1 col2" >25</td>
#       <td id="T_4f142_row1_col3" class="data row1 col3" >18</td>
#       <td id="T_4f142_row1_col4" class="data row1 col4" >28</td>
#       <td id="T_4f142_row1_col5" class="data row1 col5" >21</td>
#       <td id="T_4f142_row1_col6" class="data row1 col6" >19</td>
#       <td id="T_4f142_row1_col7" class="data row1 col7" >26</td>
#     </tr>
#     <tr>
#       <th id="T_4f142_level0_row2" class="row_heading level0 row2" >♥</th>
#       <td id="T_4f142_row2_col0" class="data row2 col0" >40</td>
#       <td id="T_4f142_row2_col1" class="data row2 col1" >24</td>
#       <td id="T_4f142_row2_col2" class="data row2 col2" >41</td>
#       <td id="T_4f142_row2_col3" class="data row2 col3" >38</td>
#       <td id="T_4f142_row2_col4" class="data row2 col4" >36</td>
#       <td id="T_4f142_row2_col5" class="data row2 col5" >38</td>
#       <td id="T_4f142_row2_col6" class="data row2 col6" >38</td>
#       <td id="T_4f142_row2_col7" class="data row2 col7" >35</td>
#     </tr>
#     <tr>
#       <th id="T_4f142_level0_row3" class="row_heading level0 row3" >♠</th>
#       <td id="T_4f142_row3_col0" class="data row3 col0" >28</td>
#       <td id="T_4f142_row3_col1" class="data row3 col1" >25</td>
#       <td id="T_4f142_row3_col2" class="data row3 col2" >29</td>
#       <td id="T_4f142_row3_col3" class="data row3 col3" >33</td>
#       <td id="T_4f142_row3_col4" class="data row3 col4" >14</td>
#       <td id="T_4f142_row3_col5" class="data row3 col5" >21</td>
#       <td id="T_4f142_row3_col6" class="data row3 col6" >34</td>
#       <td id="T_4f142_row3_col7" class="data row3 col7" >21</td>
#     </tr>
#   </tbody>
# </table>
